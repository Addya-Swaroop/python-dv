# %% [markdown]
# type casting and type conversion
# two types

# %% [markdown]
# implicit ytpe catsing and explicit type casting

# %%
#implicit type casting
a=10
b=3.5
c=a+b
print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# 10 <class 'int'>
# 3.5 <class 'float'>
# 13.5 <class 'float'>

# %%
age=25
print(age, type(age))
agestr=str(age)
print(agestr, type(agestr))
# Out:
# 25 <class 'int'>
# 25 <class 'str'>

# %%
age=int(input("enter our age:"))
print(age, type(age))
# Out:
# 52 <class 'int'>

# %%
num1=float(input("enter first number:")) 
num2=float(input("enter second number:"))
sum=num1+num2
diffrence=num1-num2
product=num1*num2
quotient=num1/num2
print("sum:", sum)
print("difference:", diffrence)
print("product:", product)
print("quotient:", quotient)
# Out:
# sum: 107.0
# difference: -17.0
# product: 2790.0
# quotient: 0.7258064516129032

# %%
a=10
b=5
add=a+b
sub=a-b
mult=a*b
div=a/b
floor=a//b
modul=a%b
expo=a**b
print(add)
print(sub)
print(mult)
print(div)
print(expo)
print(floor)
print(modul)
# Out:
# 15
# 5
# 50
# 2.0
# 100000
# 2
# 0

# %%
c='f'
d='h'
e=d+c
print (e)
# Out:
# hf

# %%
print ("hello "*5)
# Out:
# hello hello hello hello hello

# %%
a=34
b=45
print(
    a<b,
    a>b,
    a<=b,
    a>=b,
    a==b,
    a!=b,
)
# Out:
# True False True False False True

# %%
a=89
b=24
print(
    a&b,
    a^b,
    a|b,

    a<<b
)
# Out:
# 24 65 89 1493172224

# %%
x=9
print(x)
x+=5
print(x)
x-=2
print(x)
x*=6
print(x)
x/=8
print(x)
x**=2
print(x)
x%=3
print(x)
# Out:
# 9
# 14
# 12
# 72
# 9.0
# 81.0
# 0.0

# %%
a=10
b=10
print(a is not b)
print(a==b)
# Out:
# False
# True

# %%
import copy
a=10
b=copy.copy(a)
print(a is not b)

print(a==b)
print(id(a),id(b))
# Out:
# False
# True
# 140720193893576 140720193893576
